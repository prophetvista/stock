# %%
#程序功能：处理通达信分钟数据 
#通达信数据格式如下：
''' date	    time	open	high	low	    close	volume	    amount
0	2019/09/05	0931	35.03	35.29	35.03	35.25	2539100.0	89284688.0
1	2019/09/05	0932	35.22	35.25	35.18	35.23	865400.0	30479884.0
2	2019/09/05	0933	35.23	35.38	35.23	35.35	1199300.0	42378484.0
3	2019/09/05	0934	35.31	35.37	35.28	35.28	880400.0	31111320.0
'''
#根据分钟，计算从9:31分到现在为止的累计成交量与成交额，实时对比判断成交是否放大
import pandas as pd
import numpy as np
data_type={'time': np.str_}
time_input='1120'
data2=pd.read_csv(r'd:\MyProgram\tdx\T0002\export\SH#600036.txt',sep='\t',encoding = 'ANSI',header=None,skiprows=2,names=['date','time','open','high','low','close','volume','amount'],dtype=data_type)

datastrip=[]
for i in data:
    if i not in datastrip:
        datastrip.append(i)
datastrip[:-2]
h=time_input[:2]
m=time_input[2:]
endtime=h+':'+m
timelist=pd.date_range('09:31', endtime, freq='Min')
for i in timelist:
    timelista=str(i)[-8:-3].replace(':', '')
    print(timelista)
# Out:
# 0931
# 0932
# 0933
# 0934
# 0935
# 0936
# 0937
# 0938
# 0939
# 0940
# 0941
# 0942
# 0943
# 0944
# 0945
# 0946
# 0947
# 0948
# 0949
# 0950
# 0951
# 0952
# 0953
# 0954
# 0955
# 0956
# 0957
# 0958
# 0959
# 1000
# 1001
# 1002
# 1003
# 1004
# 1005
# 1006
# 1007
# 1008
# 1009
# 1010
# 1011
# 1012
# 1013
# 1014
# 1015
# 1016
# 1017
# 1018
# 1019
# 1020
# 1021
# 1022
# 1023
# 1024
# 1025
# 1026
# 1027
# 1028
# 1029
# 1030
# 1031
# 1032
# 1033
# 1034
# 1035
# 1036
# 1037
# 1038
# 1039
# 1040
# 1041
# 1042
# 1043
# 1044
# 1045
# 1046
# 1047
# 1048
# 1049
# 1050
# 1051
# 1052
# 1053
# 1054
# 1055
# 1056
# 1057
# 1058
# 1059
# 1100
# 1101
# 1102
# 1103
# 1104
# 1105
# 1106
# 1107
# 1108
# 1109
# 1110
# 1111
# 1112
# 1113
# 1114
# 1115
# 1116
# 1117
# 1118
# 1119
# 1120
